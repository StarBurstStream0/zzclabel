# %%
from read_file import *
from vis_file import *
from write_file import *
# Out:
# /***
#  *             ,%%%%%%%%,
#  *           ,%%/\%%%%/\%%
#  *          ,%%%\c "" J/%%%
#  * %.       %%%%/ o  o \%%%
#  * `%%.     %%%%    _  |%%%
#  *  `%%     `%%%%(__Y__)%%%
#  *  //       ;%%%%`\-/%%%%
#  * ((       /  `%%%%%%%%
#  *  \    ./          |
#  *   \  /       \  | |
#  *    \/         ) | |
#  *     \         /_ | |__
#  *     (___________))))))) ZZC GO!~

# %%
txt_dir = '/home/zzc/All/playground/20210422_zzclabel/txt_format/labels'
img_dir = '/home/zzc/All/playground/20210422_zzclabel/txt_format/images'
vis_dir = '/home/zzc/All/playground/20210422_zzclabel/txt_format/vis'
save_dir = '/home/zzc/All/playground/20210422_zzclabel/txt_format/darknet_format'

# %%
ann_dict = read_txt(txt_dir, img_dir, format='result', ext='bmp')
# Out:
# [INFO]    [Mon May 10 16:46:15 2021] [zzc]:  Start to load the txt dir
# [INFO]    [Mon May 10 16:46:15 2021] [zzc]:  Start to load the txt results...
# [INFO]    [Mon May 10 16:46:15 2021] [zzc]:  class_map:  {0: 'ship'}
# ship: 100%|██████████████████████████████████████████████████| 2394/2394 [00:00<00:00, 12424.46it/s]
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000003 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000003 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000003 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000003 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000005 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000005 gets no corresponding images!
# [WARNING] [Mon May 10 16:46:16 2021] [zzc]:  100000005 gets no corresponding images!
# ...

# %%
ann_dict
# Out:
# [OrderedDict([('object',
#                [OrderedDict([('name', 'ship'),
#                              ('pose', None),
#                              ('truncated', '0'),
#                              ('difficult', '0'),
#                              ('confidence', 0.9883),
#                              ('bndbox',
#                               OrderedDict([('xmin', 622.3179),
#                                            ('ymin', 100.8487),
#                                            ('xmax', 849.0765),
#                                            ('ymax', 240.9038)])),
#                              ('segmentation',
#                               [[644.8271,
#                                 100.8487,
#                                 849.0765,
#                                 188.3798,
#                                 826.5673,
#                                 240.9038,
#                                 622.3179,
#                                 153.3727]])]),
# ...

# %%
vis_labels(ann_dict, img_dir, vis_dir)
# Out:
# [INFO]    [Mon May 10 16:46:17 2021] [zzc]:  Start to visualize images with anns...
# [INFO]    [Mon May 10 16:46:17 2021] [zzc]:  Successfully created color map...
# Visualized images: 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 244.73it/s]
# [INFO]    [Mon May 10 16:46:18 2021] [zzc]:  Finish all images visualization!

# %%
write_txt(ann_dict, save_dir, 'darknet')
# Out:
# [INFO]    [Mon May 10 16:46:18 2021] [zzc]:  Start to save parsed labels into darknet format...
# Transfered annotations: 100%|███████████████████████████████████████| 3/3 [00:00<00:00, 8484.77it/s]
# [INFO]    [Mon May 10 16:46:19 2021] [zzc]:  Finish saving all 3 instances!
# [INFO]    [Mon May 10 16:46:19 2021] [zzc]:  Finish saving data.txt file!
# [INFO]    [Mon May 10 16:46:19 2021] [zzc]:  Finish saving data.names file!
